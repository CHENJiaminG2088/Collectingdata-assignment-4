# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghistorian/jekyll/blob/Issue-3052/assets/corpus-analysis-with-spacy/corpus-analysis-with-spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Corpus Analysis with spaCy

# %% [markdown]
# ### Installing, Importing and Preprocessing

# %%
# !pip install spaCy
# !pip install plotly
# %pip install nbformat --upgrade
# Out:
# Requirement already satisfied: spaCy in /Users/meinv/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spaCy) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spaCy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spaCy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spaCy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spaCy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from jinja2->spaCy) (2.1.1)
# Requirement already satisfied: plotly in /Users/meinv/anaconda3/lib/python3.11/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from plotly) (8.2.2)
# Requirement already satisfied: nbformat in /Users/meinv/anaconda3/lib/python3.11/site-packages (5.9.2)
# Requirement already satisfied: fastjsonschema in /Users/meinv/anaconda3/lib/python3.11/site-packages (from nbformat) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from nbformat) (4.17.3)
# Requirement already satisfied: jupyter-core in /Users/meinv/anaconda3/lib/python3.11/site-packages (from nbformat) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from nbformat) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from jupyter-core->nbformat) (2.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# Install English language model
# !spacy download en_core_web_sm

# Import os to upload documents and metadata
import os

# Load spaCy visualizer
from spacy import displacy

# Import pandas DataFrame packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# Import graphing package
import plotly.graph_objects as go
import plotly.express as px
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 44.9 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Create empty lists for file names and contents
texts = []
file_names = []

# Iterate through each file in the folder
for _file_name in os.listdir('rap_lyrics'):
# Look for only text files
    if _file_name.endswith('.txt'):
    # Append contents of each text file to text list
        texts.append(open('rap_lyrics' + '/' + _file_name, 'r', encoding='latin-1').read())
        # Append name of each file to file name list
        file_names.append(_file_name)

# %%
# Create dictionary object associating each file name with its text
d = {'Filename':file_names,'Text':texts}

# %%
# Turn dictionary into a dataframe
lyrics_df = pd.DataFrame(d)

# %%
lyrics_df.head()
# Out:
#                      Filename  \
# 0      Talib Kweli_lyrics.txt
# 1  CunninLynguists_lyrics.txt
# 2       Kanye West_lyrics.txt
# 3    Deniro Farrar_lyrics.txt
# 4           Eminem_lyrics.txt
#
#                                                 Text
# 0  \nWe sell crack to our own out the back of our...
# 1  \nLove ain't for the faint of heart\nStart tra...
# 2  \nWell, it is a weepin' and a moanin' and a gn...
# 3  \nÂ­\n\nLet me give you a little inside inform...
# 4  \n"Look, I was gonna go easy on you, and not t...

# %% [markdown]
# The beginnings of some of the texts may contain extra spaces (indicated by \t or \n). These characters can be replaced by a single space using the str.replace() method.

# %%
# Remove extra spaces from papers
lyrics_df['Text'] = lyrics_df['Text'].str.replace('\s+', ' ', regex=True).str.strip()
lyrics_df.head()
# Out:
#                      Filename  \
# 0      Talib Kweli_lyrics.txt
# 1  CunninLynguists_lyrics.txt
# 2       Kanye West_lyrics.txt
# 3    Deniro Farrar_lyrics.txt
# 4           Eminem_lyrics.txt
#
#                                                 Text
# 0  We sell crack to our own out the back of our h...
# 1  Love ain't for the faint of heart Start traini...
# 2  Well, it is a weepin' and a moanin' and a gnas...
# 3  Â­ Let me give you a little inside information...
# 4  "Look, I was gonna go easy on you, and not to ...

# %%
# Load metadata.
metadata_df = pd.read_csv('metadata.csv')
metadata_df.head()
# Out:
#             Artist                        File
# 0      Talib Kweli      Talib Kweli_lyrics.txt
# 1  CunninLynguists  CunninLynguists_lyrics.txt
# 2       Kanye West       Kanye West_lyrics.txt
# 3    Deniro Farrar    Deniro Farrar_lyrics.txt
# 4           Eminem           Eminem_lyrics.txt

# %%
# Remove .txt from title of each paper
lyrics_df['Filename'] = lyrics_df['Filename'].str.replace('.txt', '', regex=True)

# Rename column from paper ID to Title
metadata_df.rename(columns={"lyrics ID": "Filename"}, inplace=True)

# %%
# 输出 metadata_df 的列名
print(metadata_df.columns)

# 输出 lyrics_df 的列名
print(lyrics_df.columns)
# Out:
# Index(['Artist', 'File'], dtype='object')
# Index(['Filename', 'Text'], dtype='object')

# %%
# Merge metadata and lyrics_df into new DataFrame
# Will only keep rows where both metadata and lyrics_df are present
merged_df = metadata_df.merge(lyrics_df, left_on='File', right_on='Filename')

# %% [markdown]
# Let's check the head of the DataFrame again to confirm everything has worked well. Check the first five rows to make sure each has a filename, title, discipline, paper type and text (the full paper)

# %%
# Print DataFrame
lyrics_df.head()
# Out:
#                  Filename                                               Text
# 0      Talib Kweli_lyrics  We sell crack to our own out the back of our h...
# 1  CunninLynguists_lyrics  Love ain't for the faint of heart Start traini...
# 2       Kanye West_lyrics  Well, it is a weepin' and a moanin' and a gnas...
# 3    Deniro Farrar_lyrics  Â­ Let me give you a little inside information...
# 4           Eminem_lyrics  "Look, I was gonna go easy on you, and not to ...

# %% [markdown]
# The resulting DataFrame is now ready for analysis.

# %% [markdown]
# ## Text Enrichment with spaCy

# %% [markdown]
# ### Creating Doc Objects

# %%
# Load nlp pipeline
nlp = spacy.load('en_core_web_sm')

# Check what functions it performs
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#Define example sentence
sentence = "This is 'an' example? sentence"

# Call the nlp model on the sentence
doc = nlp(sentence)

# %%
# Loop through each token in doc object
for token in doc:
    # Print text and part of speech for each
    print(token.text, token.pos_)
# Out:
# This PRON
# is AUX
# ' PUNCT
# an DET
# ' PUNCT
# example NOUN
# ? PUNCT
# sentence NOUN

# %%
# Define a function that runs the nlp pipeline on any given input text
def process_text(text):
    return nlp(text)

# %%
lyrics_df['Doc'] = lyrics_df['Text'][:100].apply(process_text)

# %%
# Apply the function to the "Text" column, so that the nlp pipeline is called on each student essay
lyrics_df['Doc'] = lyrics_df['Text'].apply(process_text)

# %%
print(lyrics_df)
# Out:
#                      Filename  \
# 0          Talib Kweli_lyrics
# 1      CunninLynguists_lyrics
# 2           Kanye West_lyrics
# 3        Deniro Farrar_lyrics
# 4               Eminem_lyrics
# 5             Ice Cube_lyrics
# 6       Kendrick Lamar_lyrics
# 7                Logic_lyrics
# 8               Tupac1_lyrics
# 9               J Cole_lyrics
# 10                  NF_lyrics
# 11              Eazy-E_lyrics
# 12         Joey Badass_lyrics
# 13              Common_lyrics
# 14            Scarface_lyrics
# 15       Isaiah Rashad_lyrics
# 16         Royce Da 59_lyrics
# 17               Jay-z_lyrics
# 18   Chance The Rapper_lyrics
# 19  Immortal Technique_lyrics
# 20         Lupe Fiasco_lyrics
# 21               Big L_lyrics
# 22      Montana of 300_lyrics
# 23          ASAP Rocky_lyrics
# 24                 Bas_lyrics
# 25   The Notorious BIG_lyrics
# 26     Earl Sweatshirt_lyrics
# 27           Lil Wayne_lyrics
# 28            ASAP Ant_lyrics
# 29               Drake_lyrics
# 30   Tyler The Creator_lyrics
# 31                 Nas_lyrics
# 32          Mac Miller_lyrics
# 33          Andre 3000_lyrics
# 34             Pusha-T_lyrics
# 35              Tupac2_lyrics
# 36      Action Bronson_lyrics
# 37    Childish Gambino_lyrics
#
#                                                  Text  \
# 0   We sell crack to our own out the back of our h...
# 1   Love ain't for the faint of heart Start traini...
# 2   Well, it is a weepin' and a moanin' and a gnas...
# 3   Â­ Let me give you a little inside information...
# 4   "Look, I was gonna go easy on you, and not to ...
# 5   Damn! ( Forgot to do somethin', let me see...u...
# 6   Nobody pray for me It's been that day for me W...
# 7   I've been on the low I been taking my time I f...
# 8   You know they got me trapped in this prison of...
# 9   First things first: rest in peace Uncle Phil F...
# 10  Feels like we're on the edge right now I wish ...
# 11  "Yeah, Gangsta Dresta done stepped in this, mo...
# 12  It's either, them or you It's sort of like, su...
# 13  Yeah, doo-doo-doo Doo-doo-d-doo, diggy-doo, yo...
# 14  There's gon' be some stuff you gon' see That's...
# 15  Ah, ah, ah, ah Ah, ah, ah, ah I cut my hair an...
# 16  You will not be able to stay home, brotha You ...
# 17  You'd take the clothes off my back and I'd let...
# 18  You don't want zero problems, big fella! Yep! ...
# 19  I once knew a nigga whose real name was Willia...
# 20  Yeah, I say, bitch bad Woman good, lady better...
# 21  Yo, I got slugs for snitches, no love for bitc...
# 22  Any nigga that ever looked at me wrong, (ha!) ...
# 23  I love bad bitches, that's my fuckin' problem ...
# 24  Do you still believe in love? Or do you like d...
# 25  ('Fuck all you hoes!' Get a grip, motherfucker...
# 26  Promise Heron I'll put my fist up, after I get...
# 27  ï»¿ I'm on that good kush and alcohol I got so...
# 28  Chickens in the sink Crack on the stove Triple...
# 29  Yeah, they wishin' and wishin' and wishin' and...
# 30  Uh, Wolf Haley, Golf Wang I'm a fuckin' walkin...
# 31  Yeah, yeah Ayo, Black, it's time, word (Word, ...
# 32  Yeah, yeah, yeah, yo Yeah, yeah, yeah, yo Yeah...
# 33  Me and my mother drivin' to the grocery store ...
# 34  Easy money It's about to be a surgical summer ...
# 35  ("Hard like an erection..." -- Ed O.G.) Young ...
# 36  Heartbreak drowned sorrows in a large steak Wh...
# 37  Yeah, yeah, yeah, yeah, yeah Yeah, yeah, yeah,...
#
#                                                   Doc
# 0   (We, sell, crack, to, our, own, out, the, back...
# 1   (Love, ai, n't, for, the, faint, of, heart, St...
# 2   (Well, ,, it, is, a, weepin, ', and, a, moanin...
# 3   (Â­, Let, me, give, you, a, little, inside, in...
# 4   (", Look, ,, I, was, gon, na, go, easy, on, yo...
# 5   (Damn, !, (, Forgot, to, do, somethin', ,, let...
# 6   (Nobody, pray, for, me, It, 's, been, that, da...
# 7   (I, 've, been, on, the, low, I, been, taking, ...
# 8   (You, know, they, got, me, trapped, in, this, ...
# 9   (First, things, first, :, rest, in, peace, Unc...
# 10  (Feels, like, we, 're, on, the, edge, right, n...
# 11  (", Yeah, ,, Gangsta, Dresta, done, stepped, i...
# 12  (It, 's, either, ,, them, or, you, It, 's, sor...
# 13  (Yeah, ,, doo, -, doo, -, doo, Doo, -, doo, -,...
# 14  (There, 's, gon, ', be, some, stuff, you, gon,...
# 15  (Ah, ,, ah, ,, ah, ,, ah, Ah, ,, ah, ,, ah, ,,...
# 16  (You, will, not, be, able, to, stay, home, ,, ...
# 17  (You, 'd, take, the, clothes, off, my, back, a...
# 18  (You, do, n't, want, zero, problems, ,, big, f...
# 19  (I, once, knew, a, nigga, whose, real, name, w...
# 20  (Yeah, ,, I, say, ,, bitch, bad, Woman, good, ...
# 21  (Yo, ,, I, got, slugs, for, snitches, ,, no, l...
# 22  (Any, nigga, that, ever, looked, at, me, wrong...
# 23  (I, love, bad, bitches, ,, that, 's, my, fucki...
# 24  (Do, you, still, believe, in, love, ?, Or, do,...
# 25  ((, ', Fuck, all, you, hoes, !, ', Get, a, gri...
# 26  (Promise, Heron, I, 'll, put, my, fist, up, ,,...
# 27  (ï, », ¿, I, 'm, on, that, good, kush, and, al...
# 28  (Chickens, in, the, sink, Crack, on, the, stov...
# 29  (Yeah, ,, they, wishin, ', and, wishin, ', and...
# 30  (Uh, ,, Wolf, Haley, ,, Golf, Wang, I, 'm, a, ...
# 31  (Yeah, ,, yeah, Ayo, ,, Black, ,, it, 's, time...
# 32  (Yeah, ,, yeah, ,, yeah, ,, yo, Yeah, ,, yeah,...
# 33  (Me, and, my, mother, drivin, ', to, the, groc...
# 34  (Easy, money, It, 's, about, to, be, a, surgic...
# 35  ((, ", Hard, like, an, erection, ..., ", --, E...
# 36  (Heartbreak, drowned, sorrows, in, a, large, s...
# 37  (Yeah, ,, yeah, ,, yeah, ,, yeah, ,, yeah, Yea...

# %% [markdown]
# ### Text Reduction

# %% [markdown]
# #### Tokenization
#
# A critical first step spaCy performs is tokenization, or the segmentation of strings into individual words and punctuation markers. Tokenization enables spaCy to parse the grammatical structures of a text and identify characteristics of each word-like part-of-speech.
#
# To retrieve a tokenized version of each text in the DataFrame, we’ll write a function that iterates through any given Doc object and returns all functions found within it.

# %%
# Define a function to retrieve tokens from a doc object
def get_token(doc):
    return [(token.text) for token in doc]

# %%
# Run the token retrieval function on the doc objects in the dataframe
lyrics_df['Tokens'] = lyrics_df['Doc'].apply(get_token)
lyrics_df.head()
# Out:
#                  Filename                                               Text  \
# 0      Talib Kweli_lyrics  We sell crack to our own out the back of our h...
# 1  CunninLynguists_lyrics  Love ain't for the faint of heart Start traini...
# 2       Kanye West_lyrics  Well, it is a weepin' and a moanin' and a gnas...
# 3    Deniro Farrar_lyrics  Â­ Let me give you a little inside information...
# 4           Eminem_lyrics  "Look, I was gonna go easy on you, and not to ...
#
#                                                  Doc  \
# 0  (We, sell, crack, to, our, own, out, the, back...
# 1  (Love, ai, n't, for, the, faint, of, heart, St...
# 2  (Well, ,, it, is, a, weepin, ', and, a, moanin...
# 3  (Â­, Let, me, give, you, a, little, inside, in...
# 4  (", Look, ,, I, was, gon, na, go, easy, on, yo...
#
#                                               Tokens
# 0  [We, sell, crack, to, our, own, out, the, back...
# 1  [Love, ai, n't, for, the, faint, of, heart, St...
# 2  [Well, ,, it, is, a, weepin, ', and, a, moanin...
# 3  [Â­, Let, me, give, you, a, little, inside, in...
# 4  [", Look, ,, I, was, gon, na, go, easy, on, yo...

# %%
tokens = lyrics_df[['Text', 'Tokens']].copy()
tokens.head()
# Out:
#                                                 Text  \
# 0  We sell crack to our own out the back of our h...
# 1  Love ain't for the faint of heart Start traini...
# 2  Well, it is a weepin' and a moanin' and a gnas...
# 3  Â­ Let me give you a little inside information...
# 4  "Look, I was gonna go easy on you, and not to ...
#
#                                               Tokens
# 0  [We, sell, crack, to, our, own, out, the, back...
# 1  [Love, ai, n't, for, the, faint, of, heart, St...
# 2  [Well, ,, it, is, a, weepin, ', and, a, moanin...
# 3  [Â­, Let, me, give, you, a, little, inside, in...
# 4  [", Look, ,, I, was, gon, na, go, easy, on, yo...

# %% [markdown]
# #### Lemmatization

# %%
# Define a function to retrieve lemmas from a doc object
def get_lemma(doc):
    return [(token.lemma_) for token in doc]

# Run the lemma retrieval function on the doc objects in the dataframe
lyrics_df['Lemmas'] = lyrics_df['Doc'].apply(get_lemma)

# %% [markdown]
# Lemmatization can help reduce noise and refine results for researchers who are conducting keyword searches. For example, let’s compare counts of the word “write” in the original Tokens column and in the lemmatized Lemmas column.

# %%
print(f'"money" appears in the text tokens column ' + str(lyrics_df['Tokens'].apply(lambda x: x.count('write')).sum()) + ' times.')
print(f'"money" appears in the lemmas column ' + str(lyrics_df['Lemmas'].apply(lambda x: x.count('write')).sum()) + ' times.')
# Out:
# "money" appears in the text tokens column 242 times.
# "money" appears in the lemmas column 585 times.

# %% [markdown]
# ### Text Annotation

# %%
# Define a function to retrieve lemmas from a doc object
def get_pos(doc):
    #Return the coarse- and fine-grained part of speech text for each token in the doc
    return [(token.pos_, token.tag_) for token in doc]

# Define a function to retrieve parts of speech from a doc object
lyrics_df['POS'] = lyrics_df['Doc'].apply(get_pos)

# %%
# Create a list of part of speech tags
list(lyrics_df['POS'])
# Out:
# [[('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'RP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('VERB', 'VBD'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADP', 'RP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'RP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'RP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('AUX', 'VBN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'DT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', '.'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PART', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'DT'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBP'),
#   ('AUX', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('VERB', 'VBP'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'RP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'RP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('AUX', 'VBN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADV', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('PROPN', 'NNPS'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PRON', 'NN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('NUM', 'CD'),
#   ('VERB', 'VBP'),
#   ('PRON', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('PRON', 'NN'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'NN'),
#   ('ADV', 'RB'),
#   ('PRON', 'DT'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PRON', 'NN'),
#   ('PUNCT', '``'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PRON', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('PROPN', 'NNPS'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('PRON', 'NN'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('NOUN', 'NN'),
#   ...],
#  [('NOUN', 'NN'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('ADP', 'RP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('ADJ', 'JJ'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'WRB'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('AUX', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '.'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ':'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('AUX', 'VBN'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'DT'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NNS'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '``'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PUNCT', "''"),
#   ('AUX', 'VBZ'),
#   ('PART', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RBS'),
#   ('VERB', 'VBP'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJR'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('PART', 'RB'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJS'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('PART', 'RB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBG'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('PRON', 'NN'),
#   ('SCONJ', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'RP'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADJ', 'JJ'),
#   ('ADJ', 'JJ'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'HYPH'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBG'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBG'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('ADP', 'RP'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('VERB', 'VBG'),
#   ('PRON', 'DT'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'DT'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBG'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('AUX', 'VBN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NUM', 'CD'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBG'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP$'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'WRB'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PRON', 'WP'),
#   ('AUX', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('PART', 'RB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('AUX', 'VBG'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PUNCT', '``'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PUNCT', "''"),
#   ('PUNCT', '``'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PUNCT', "''"),
#   ('PUNCT', '``'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-RRB-'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-LRB-'),
#   ('SCONJ', 'WRB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('SCONJ', 'WRB'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJR'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NNS'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-LRB-'),
#   ('SCONJ', 'IN'),
#   ('ADJ', 'JJS'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RBR'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PUNCT', '-LRB-'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('ADJ', 'JJR'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJR'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJS'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJR'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('INTJ', 'UH'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NNS'),
#   ...],
#  [('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADP', 'IN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VBP'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VBP'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('PUNCT', ':'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'RP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ':'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'DT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('ADV', 'RB'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJS'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'RP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PUNCT', ':'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('SCONJ', 'IN'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VBP'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('PRON', 'PRP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VBP'),
#   ('PUNCT', '-RRB-'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADP', 'IN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
# ...
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PRON', 'DT'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PRON', 'DT'),
#   ('VERB', 'VB'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PRON', 'DT'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('PUNCT', "''"),
#   ('NOUN', 'NN'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-LRB-'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VB'),
#   ('PRON', 'NN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PUNCT', '-RRB-'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBN'),
#   ('PUNCT', '-LRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PUNCT', "''"),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('AUX', 'VBG'),
#   ('PUNCT', "''"),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'DT'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '-RRB-'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('PUNCT', '-LRB-'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '-LRB-'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PUNCT', '``'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('PUNCT', '-LRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP$'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VB'),
#   ('PRON', 'NN'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VB'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('NUM', 'CD'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('VERB', 'VB'),
#   ('PRON', 'NN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PUNCT', '``'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-LRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('INTJ', 'UH'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'RP'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBG'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('SCONJ', 'IN'),
#   ...]]

# %% [markdown]
# Fortunately, spaCy has a built-in function called explain that can provide a short description of any tag of interest. If we try it on the tag IN using spacy.explain("IN"), the output reads conjunction, subordinating or preposition.

# %%
spacy.explain("IN")
# Out:
# 'conjunction, subordinating or preposition'

# %% [markdown]
# In some cases, you may want to get only a set of part-of-speech tags for further analysis, like all of the proper nouns. A function can be written to perform this task, extracting only words which have been fitted with the proper noun tag.

# %%
# Define function to extract proper nouns from Doc object
def extract_proper_nouns(doc):
    return [token.text for token in doc if token.pos_ == 'PROPN']

# Apply function to Doc column and store resulting proper nouns in new column
lyrics_df['Proper_Nouns'] = lyrics_df['Doc'].apply(extract_proper_nouns)

# %%
print(len(lyrics_df))
# Out:
# 38

# %%
lyrics_df.iloc[:, lyrics_df.columns.get_loc('Proper_Nouns')]
# Out:
# 0     [Attack, Clones, Work, ', Norman, Mailer, Mi, ...
# 1     [Cause, Love, Love'll, Brain, Studderin, Furth...
# 2     [Believe, Lamborghini, Mercy, I, Lambo, Lambor...
# 3     [God, Nigga, OG, niggas, Nigga, New, god, Nigg...
# 4     [Minutes, Slim, Shady, doc, Rap, God, Rap, God...
# 5     [yeahâit, Y'all, N.W.A, âIt, dopeââ, â...
# 6     [Waaaaay, Ayy, Finesse, countin, Parmesan, D'U...
# 7     [Woo, wanna, wanna, Woo, lemme, God, Woo, Pain...
# 8     [Happiness, tha, Walk, tha, tha, Niggas, Gette...
# 9     [Uncle, Phil, Prophecies, Ville, Martin, Luthe...
# 10    [Le, Lookin, Paranoia, Shoulda, itâmy, butâ...
# 11    [Gangsta, Dresta, O.G., west, coast, shit, E, ...
# 12    [Niggas, warâI'm, martian, Brooklyn, P, -, Y...
# 13    [Doo, doo, doo, diggy, doo, yo, Special, luh, ...
# 14    [Mmm, Pictures, hell, Hustlers, Sellin, Wishin...
# 15    [Kaio, Ken, LA, Pour, Bowl, niggas, Hill, clif...
# 16    [Ohh, dyin, ahh, Parker, Lewis, Kubiak, hyenas...
# 17    [warnin, warnin, Hang, warnin, warnin, Sippin,...
# 18    [Yep, ya, Chano, Chano, Countin, Benjis, meeti...
# 19    [William, Bein, illest, sniff, coke, Nigga, Ch...
# 20    [Woman, Niggas, happenin, First, â, Bitch, L...
# 21    [Yo, Puttin, Keith, Sweat, L, Leavin, Big, L, ...
# 22    [B, Hey, holdin, Y'all, Montana, Bust, Percy, ...
# 23    [fuckin, Takin, Ooh, ya, Huh, AP, Keith, nigga...
# 24    [rollin, White, Owls, Girl, White, Owl, Europe...
# 25    [hustlin, tryin, Word, Up, Salt, Heavy, D, Han...
# 26    [Promise, Heron, Quick, s, Stone, nigga, Stamp...
# 27    [', Lil, Tunechi, Satan, Karrine, A1, Baby, ',...
# 28    [Crack, Colombia, Riding, Benz, Tryna, Fucking...
# 29    [wishin, wishin, movin, Tryna, Hope, God, God,...
# 30    [Wolf, Haley, Golf, Wang, fuckin, â, Reptar,...
# 31    [Ayo, Black, Aight, yo, Rappers, kickin, Scarf...
# 32    [yo, yo, yo, yo, Yo, fillin, Doctor, Ooh, Smok...
# 33    [Hustlin, Cognac, Zen, Aaliyah, Age, Crawl, Cr...
# 34    [Chop, ochenta, y, Spider, Drug, M, Baby, fron...
# 35    [Ed, O.G., Ice, Cube, 2Pac, Young, Verse, jack...
# 36    [Benz, Doc, Gooden, Dark, Girl, Brazilians, La...
# 37    [wanna, party, Party, wanna, party, Party, dan...
# Name: Proper_Nouns, dtype: object

# %% [markdown]
# #### Named Entity Recognition
#
# spaCy can tag named entities in the text, such as names, dates, organizations, and locations. Call the full list of named entities and their descriptions using this code:

# %%
# Get all NE labels and assign to variable
labels = nlp.get_pipe("ner").labels

# Print each label and its description
for label in labels:
    print(label + ' : ' + spacy.explain(label))
# Out:
# CARDINAL : Numerals that do not fall under another type
# DATE : Absolute or relative dates or periods
# EVENT : Named hurricanes, battles, wars, sports events, etc.
# FAC : Buildings, airports, highways, bridges, etc.
# GPE : Countries, cities, states
# LANGUAGE : Any named language
# LAW : Named documents made into laws.
# LOC : Non-GPE locations, mountain ranges, bodies of water
# MONEY : Monetary values, including unit
# NORP : Nationalities or religious or political groups
# ORDINAL : "first", "second", etc.
# ORG : Companies, agencies, institutions, etc.
# PERCENT : Percentage, including "%"
# PERSON : People, including fictional
# PRODUCT : Objects, vehicles, foods, etc. (not services)
# QUANTITY : Measurements, as of weight or distance
# TIME : Times smaller than a day
# WORK_OF_ART : Titles of books, songs, etc.

# %% [markdown]
# We’ll create a function to extract the named entity tags from each Doc object and apply it to the Doc objects in the DataFrame, storing the named entities in a new column:

# %%
# Define function to extract named entities from doc objects
def extract_named_entities(doc):
    return [ent.label_ for ent in doc.ents]

# Apply function to Doc column and store resulting named entities in new column
lyrics_df['Named_Entities'] = lyrics_df['Doc'].apply(extract_named_entities)
lyrics_df['Named_Entities']
# Out:
# 0     [ORG, PERSON, CARDINAL, ORG, PERSON, PERSON, T...
# 1     [PRODUCT, WORK_OF_ART, PERSON, ORG, GPE, CARDI...
# 2     [ORG, CARDINAL, PERSON, CARDINAL, PERSON, PERS...
# 3     [PERSON, CARDINAL, ORG, PERSON, CARDINAL, PERS...
# 4     [CARDINAL, TIME, TIME, PERSON, PERSON, CARDINA...
# 5     [NORP, ORG, PERSON, GPE, ORG, GPE, WORK_OF_ART...
# 6     [PERSON, PERSON, PRODUCT, ORG, PERSON, PERSON,...
# 7     [DATE, DATE, ORDINAL, DATE, TIME, DATE, PERSON...
# 8     [ORG, PERSON, CARDINAL, DATE, ORG, DATE, ORG, ...
# 9     [ORDINAL, ORDINAL, PERSON, ORG, GPE, ORG, PERS...
# 10    [ORDINAL, PERSON, PERSON, ORG, PERSON, ORG, DA...
# 11    [PERSON, ORG, GPE, ORDINAL, PERSON, GPE, PERSO...
# 12    [GPE, PERSON, NORP, GPE, EVENT, PERSON, PERSON...
# 13    [PERSON, WORK_OF_ART, TIME, PERSON, ORG, DATE,...
# 14    [NORP, NORP, PERSON, PERSON, PERSON, PERSON, D...
# 15    [PERSON, PERSON, GPE, ORG, PERSON, ORG, PERSON...
# 16    [CARDINAL, CARDINAL, ORG, PERSON, ORG, GPE, PE...
# 17    [DATE, DATE, DATE, DATE, PERSON, WORK_OF_ART, ...
# 18    [CARDINAL, CARDINAL, DATE, DATE, PERSON, ORG, ...
# 19    [PERSON, LOC, CARDINAL, PERSON, DATE, PERSON, ...
# 20    [CARDINAL, CARDINAL, ORDINAL, PERSON, PERSON, ...
# 21    [ORG, PERSON, PERSON, ORG, CARDINAL, NORP, ORG...
# 22    [PERSON, PERSON, GPE, PRODUCT, CARDINAL, CARDI...
# 23    [PERSON, PERSON, ORG, PERSON, ORG, PRODUCT, PE...
# 24    [LOC, ORG, PERSON, ORG, ORG, PERSON, PRODUCT, ...
# 25    [ORG, PERSON, PERSON, PERSON, PERSON, PERSON, ...
# 26    [ORG, CARDINAL, CARDINAL, CARDINAL, QUANTITY, ...
# 27    [DATE, GPE, PERSON, CARDINAL, PRODUCT, DATE, P...
# 28    [PERSON, CARDINAL, GPE, PERSON, DATE, CARDINAL...
# 29    [PERSON, TIME, FAC, ORG, PERSON, PERSON, PERSO...
# 30    [PERSON, PERSON, PERSON, GPE, PERSON, GPE, PER...
# 31    [PERSON, NORP, PERSON, PERSON, PERSON, CARDINA...
# 32    [PERSON, PERSON, PERSON, PERSON, DATE, DATE, D...
# 33    [PERSON, PERSON, GPE, PERSON, PERSON, GPE, GPE...
# 34    [PERSON, PERSON, DATE, PERSON, PERSON, PERSON,...
# 35    [PERSON, CARDINAL, PERSON, PERSON, CARDINAL, C...
# 36    [PERSON, PERSON, CARDINAL, NORP, PERSON, DATE,...
# 37    [GPE, GPE, GPE, GPE, PERSON, GPE, GPE, PERSON,...
# Name: Named_Entities, dtype: object

# %% [markdown]
# We can add another column with the words and phrases identified as named entities:

# %%
# Define function to extract text tagged with named entities from doc objects
def extract_named_entities(doc):
    return [ent for ent in doc.ents]

# Apply function to Doc column and store resulting text in new column
lyrics_df['NE_Words'] = lyrics_df['Doc'].apply(extract_named_entities)
lyrics_df['NE_Words']
# Out:
# 0     [(the, Clones, Work, '), (Norman, Mailer, Mi),...
# 1     [(Visits), (Love), (Love'll), (Brain), (Studde...
# 2     [(Believe), (two), (Lambo), (two), (Lambo), (L...
# 3     [(Nigga), (36), (OG), (Nigga), (16), (Nigga), ...
# 4     [(one), (Six, minutes), (Six, minutes), (Slim,...
# 5     [(yeahâit), (N.W.A), (âIt), (dopeââ), ...
# 6     [(Waaaaay), (Finesse), (Iâm, countin, '), (K...
# 7     [(today), (today), (first), (the, day), (a, li...
# 8     [(Happiness), (Shot), (Nine), (daily), (Niggas...
# 9     [(First), (first), (Phil), (Prophecies), (Vill...
# 10    [(first), (Lookin), (Paranoia), (Shoulda), (bu...
# 11    [(Gangsta, Dresta), (O.G.), (west, coast), (fi...
# 12    [(Niggas), (warâI'm), (martian), (Brooklyn),...
# 13    [(Queen), (Love), (night), (Chi, night, 's), (...
# 14    [(Pictures), (Hustlers), (Sellin), (Livin), (N...
# 15    [(Tithes), (Kaio, Ken), (LA), (Pour), (Bowl), ...
# 16    [(one), (number, one), (caterpillar), (Ohh), (...
# 17    [(One, day), (The, next, day), (One, day), (on...
# 18    [(zero), (one), (Just, another, day), (Just, a...
# 19    [(William), (the, illest, hustler), (thirteen)...
# 20    [(five), (four), (First), (â), (Bitch), (twe...
# 21    [(Puttin), (Keith, Sweat), (Leavin), (Big, L),...
# 22    [(holdin), (Y'all), (Montana), (300, 1), (14),...
# 23    [(Takin), (ya, Huh), (AP), (Keith), (Gettin), ...
# 24    [(Europe), (Interpol), (ho, Stamp), (Cheefin),...
# 25    [(Salt, -, n, -, Pepa), (Hangin), (Rap, Attack...
# 26    [(Stone), (six), (one), (One), (six, -, nigga)...
# 27    [(the, day), (Satan), (Fuck), (ten), (A1), (th...
# 28    [(Cut), (8), (Colombia), (Benz), (the, next, d...
# 29    [(Tryna), (6, AM), (Weston, Road), (G.O.D.), (...
# 30    [(Wolf, Haley), (Golf, Wang), (Reptar, Rappin,...
# 31    [(Rappers), (Musician), (Scarface), (Holdin), ...
# 32    [(yo, Yo), (Keep), (Ooh), (Smokin), (the, week...
# 33    [(Hustlin), (Cognac), (Aaliyah), (Claire, Huxt...
# 34    [(Spider), (Drug, dealin, '), (the, past, few,...
# 35    [(Ed, O.G.), (2Pac), (niggaz), (Young), (2Pac)...
# 36    [(Doc, Gooden, Dark), (Girl), (five), (Brazili...
# 37    [(America), (America), (America), (America), (...
# Name: NE_Words, dtype: object

# %% [markdown]
# Let’s visualize the words and their named entity tags in a single text. Call the first text’s Doc object and use displacy.render to visualize the text with the named entities highlighted and tagged:

# %%
# Extract the first Doc object
doc = lyrics_df['Doc'][1]

# Visualize named entity tagging in a single paper
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Love ain't for the faint of heart Start training, this game is hard And arduous, you're gonna play in the dark, like when it rains in the park You're hardly conscious of the stains and scars, enabling your partly clouded logic To pay to impart bliss with arrangements of chocolates Now, you're working yourself out the same as when you strain' with a nautilus And you're willing to embrace pain facing sustained negative consequence If nothing you say when in love is embedded with common sense Then, do you really regret when you've shredded your promises? Now, I've tested the waters, kid. Sipped it; rippled the pond a bit
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Visits
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  have been abolished, and this shit's killing my confidence Is this filling your conscience when distance is an accomplishment? If you miss chicks when they're around, the phrase &quot;Let's quit&quot; isn't an option You best fix whatever's wrong and just move on and get on with it Cause, You'll catch bigger fish in the sea if you manage not to drown in it It's sad, but proud or not, most your standards go down a notch When loneliness drinks at the bar you set too high Cause, It isn't really my time, is it? Shit, I just found the watch But hearing the bell toll for me twice a day, has me fearing my grandfather clock And I can't die without trying, my hands tied in knots Knowing that I'll never learn to brave the waves if I stand by the docks
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Love
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  is hampered by thought, if you can handle the prospect of Death - it's as massive a shock And to intellects, it's a fuckin' smack in the crotch It's a cancer that rots your soul, tosses demons off of the road Just use caution and know, that, love ain't nothing but a loss of control Off then, we go Traces of love, long ago That didn't work out Traces of love, long ago That didn't work out
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Love'll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  have you nervous, doing stupid shit on purpose
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  out of service, words slurred when you blurt shit
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Studderin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ', utterin' non-sensical shit in your verses Feeling like a shirtless
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -breasted woman in a circus
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Furthurly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  trying to gap an unfillable void Because of parents never transfering that unbillical joy So girls create a false world of filling on boys
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Exploited
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , guys playing with her heart like her feelings are toys But when you have it, there's nothing like it, you get excited Seeking those who provide it, on phones talking to psychics Some fear it, spend their entire lives trying to fight it Living in a confusing
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hayes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , like they're grooving to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Isaac
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  It ain't the end of the rainbow with a treasure chest and a map It ain't easily learnable with definitions in tact It can ride your train of thought and demolition your tracks
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hittin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ' and bullwhippin you, leavin' them slits in your back But I've been a lucky one, loving parents, loving friends But I still spend alot of my life loving sin But I ain't a genius on it, I can only pretend Cause over all it's an emotion I cannot comprehend It's love
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Love
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  ain't the basis for action In a nation of addicts pacing and waiting for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of satisfaction Where the word itself is only fashioned in fits of passion Hand in hand with animalistic orgasmic reaction And the past isn't felt as a match made in hell But rather its held as a latter day meld Of common mistakes and nice intentions But when false love retention is simply vice invention It's only right to mention the fights you get in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nightly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  visions of these
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; marg

# %% [markdown]
# ### Download Enriched Dataset
#
# To save the dataset of doc objects, text reductions and linguistic annotations generated with spaCy, download the final_paper_df DataFrame to your local computer as a .csv file:

# %%
# Save DataFrame as csv (in Google Drive)
# Use this step only to save  csv to your computer's working directory
lyrics_df.to_csv('rap_lyrics_with_spaCy_tags.csv')

# %% [markdown]
# ## Analysis of Linguistic Annotations

# %% [markdown]
# ### Part of Speech Analysis
#
# In this section, we’ll analyze the part-of-speech tags extracted by spaCy to answer the first research question: Do students use certain parts-of-speech more frequently in Biology texts versus English texts, and does this signify differences in disciplinary conventions?
#
# spaCy counts the number of each part-of-speech tag that appears in each document (for example the number of times the NOUN tag appears in a document). This is called using doc.count_by(spacy.attrs.POS). Here’s how it works on a single sentence:

# %%
# Create doc object from single sentence
doc = nlp("This is 'an' example? sentence")

# Print counts of each part of speech in sentence
print(doc.count_by(spacy.attrs.POS))
# Out:
# {95: 1, 87: 1, 97: 3, 90: 1, 92: 2}

# %% [markdown]
# spaCy generates a dictionary where the values represent the counts of each part-of-speech term found in the text. The keys in the dictionary correspond to numerical indices associated with each part-of-speech tag. To make the dictionary more legible, let’s associate the numerical index values with their corresponding part of speech tags. In the example below, it’s now possible to see which parts-of-speech tags correspond to which counts:

# %%
# Store dictionary with indexes and POS counts in a variable
num_pos = doc.count_by(spacy.attrs.POS)

dictionary = {}

# Create a new dictionary which replaces the index of each part of speech for its label (NOUN, VERB, ADJECTIVE)
for k,v in sorted(num_pos.items()):
  dictionary[doc.vocab[k].text] = v

dictionary
# Out:
# {'AUX': 1, 'DET': 1, 'NOUN': 2, 'PRON': 1, 'PUNCT': 3}

# %% [markdown]
# To get the same type of dictionary for each text in a DataFrame, a function can be created to nest the above for loop. First, we’ll create a new DataFrame for the purposes of part-of speech analysis, containing the text filenames, disciplines, and Doc objects. We can then apply the function to each Doc object in the new DataFrame. In this case (and above), we are interested in the simpler, coarse-grained parts of speech.

# %%
# Create new DataFrame for analysis purposes
pos_analysis_df = lyrics_df[['Filename', 'Doc']]

# Create list to store each dictionary
num_list = []

# Define a function to get part-of-speech tags and counts and append them to a new dictionary
def get_pos_tags(doc):
    dictionary = {}
    num_pos = doc.count_by(spacy.attrs.POS)
    for k, v in sorted(num_pos.items()):
        dictionary[doc.vocab[k].text] = v
    return dictionary

# Apply function to each doc object in DataFrame and create a new column 'POS_Counts'
pos_analysis_df['POS_Counts'] = pos_analysis_df['Doc'].apply(get_pos_tags)

# Display the updated DataFrame
pos_analysis_df.head()
# Out:
#                  Filename                                                Doc  \
# 0      Talib Kweli_lyrics  (We, sell, crack, to, our, own, out, the, back...
# 1  CunninLynguists_lyrics  (Love, ai, n't, for, the, faint, of, heart, St...
# 2       Kanye West_lyrics  (Well, ,, it, is, a, weepin, ', and, a, moanin...
# 3    Deniro Farrar_lyrics  (Â­, Let, me, give, you, a, little, inside, in...
# 4           Eminem_lyrics  (", Look, ,, I, was, gon, na, go, easy, on, yo...
#
#                                           POS_Counts
# 0  {'ADJ': 1999, 'ADP': 3829, 'ADV': 1660, 'AUX':...
# 1  {'ADJ': 1703, 'ADP': 3024, 'ADV': 1389, 'AUX':...
# 2  {'ADJ': 1852, 'ADP': 3044, 'ADV': 2089, 'AUX':...
# 3  {'ADJ': 1525, 'ADP': 2860, 'ADV': 1422, 'AUX':...
# 4  {'ADJ': 2849, 'ADP': 4970, 'ADV': 3326, 'AUX':...

# %% [markdown]
# From here, we’ll take the part-of-speech counts and put them into a new DataFrame where we can calculate the frequency of each part-of-speech per document. In the new DataFrame, if a paper does not contain a particular part-of-speech, the cell will read NaN (Not a Number).

# %%
print(pos_analysis_df.columns)
# Out:
# Index(['Filename', 'Doc', 'POS_Counts'], dtype='object')

# %%
print(lyrics_df.columns)
# Out:
# Index(['Filename', 'Text', 'Doc', 'Tokens', 'Lemmas', 'POS', 'Proper_Nouns',
#        'Named_Entities', 'NE_Words'],
#       dtype='object')

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.8/636.8 kB 6.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: nltk>=3.1 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /Users/meinv/anaconda3/lib/python3.11/site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in /Users/meinv/anaconda3/lib/python3.11/site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/meinv/anaconda3/lib/python3.11/site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/meinv/anaconda3/lib/python3.11/site-packages (from nltk>=3.1->textblob) (4.65.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from textblob import TextBlob  # 需要安装 textblob：pip install textblob

# 示例歌词数据
rap_lyrics_data = {
    'Filename': ['song1.txt', 'song2.txt', 'song3.txt'],
    'Text': ['Lyrics of song 1', 'Lyrics of song 2', 'Lyrics of song 3']
}

rap_lyrics_df = pd.DataFrame(rap_lyrics_data)

# 使用 TextBlob 获取情感得分
rap_lyrics_df['Sentiment'] = rap_lyrics_df['Text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# 根据情感得分添加 'Mood' 标签
rap_lyrics_df['Mood'] = pd.cut(rap_lyrics_df['Sentiment'], bins=3, labels=['Negative', 'Neutral', 'Positive'])

# 显示更新后的 DataFrame
rap_lyrics_df.head()
# Out:
#     Filename              Text  Sentiment     Mood
# 0  song1.txt  Lyrics of song 1        0.0  Neutral
# 1  song2.txt  Lyrics of song 2        0.0  Neutral
# 2  song3.txt  Lyrics of song 3        0.0  Neutral

# %%
print(merged_df.columns)
# Out:
# Index(['Artist', 'File', 'Filename', 'Text'], dtype='object')

# %%
import pandas as pd
from textblob import TextBlob

# 示例歌词数据
rap_lyrics_data = {
    'Artist': ['Artist1', 'Artist2', 'Artist3'],
    'File': ['file1.txt', 'file2.txt', 'file3.txt'],
    'Filename': ['song1.txt', 'song2.txt', 'song3.txt'],
    'Text': ['Lyrics of song 1', 'Lyrics of song 2', 'Lyrics of song 3']
}

rap_lyrics_df = pd.DataFrame(rap_lyrics_data)

# 计算情感得分并添加 'Mood' 列
rap_lyrics_df['Sentiment'] = rap_lyrics_df['Text'].apply(lambda x: TextBlob(x).sentiment.polarity)
rap_lyrics_df['Mood'] = pd.cut(rap_lyrics_df['Sentiment'], bins=3, labels=['Negative', 'Neutral', 'Positive'])

# 显示更新后的 DataFrame
rap_lyrics_df
# Out:
#     Artist       File   Filename              Text  Sentiment     Mood
# 0  Artist1  file1.txt  song1.txt  Lyrics of song 1        0.0  Neutral
# 1  Artist2  file2.txt  song2.txt  Lyrics of song 2        0.0  Neutral
# 2  Artist3  file3.txt  song3.txt  Lyrics of song 3        0.0  Neutral

# %%
print(merged_df.columns)
# Out:
# Index(['Artist', 'File', 'Cleaned_File', 'Filename', 'Text',
#        'Cleaned_Filename'],
#       dtype='object')

# %% [markdown]
# Now you can calculate the amount of times, on average, that each part-of-speech appears in Biology versus English papers. To do so, you use the .groupby() and .mean() functions to group all part-of-speech counts from the Biology texts together and calculate the mean usage of each part-of-speech, before doing the same for the English texts. The following code also rounds the counts to the nearest whole number:

# %%
# 打印 DataFrame 的列名
print(merged_df.columns)
# Out:
# Index(['Artist', 'File', 'Cleaned_File', 'Filename', 'Text',
#        'Cleaned_Filename'],
#       dtype='object')

# %%
print("Metadata DataFrame:")
print(metadata_df.shape)
print(metadata_df.head())

print("\nLyrics DataFrame:")
print(lyrics_df.shape)
print(lyrics_df.head())
# Out:
# Metadata DataFrame:
# (5, 3)
#             Artist                        File     Cleaned_File
# 0      Talib Kweli      Talib Kweli_lyrics.txt      Talib Kweli
# 1  CunninLynguists  CunninLynguists_lyrics.txt  CunninLynguists
# 2       Kanye West       Kanye West_lyrics.txt       Kanye West
# 3    Deniro Farrar    Deniro Farrar_lyrics.txt    Deniro Farrar
# 4           Eminem           Eminem_lyrics.txt           Eminem
#
# Lyrics DataFrame:
# (5, 3)
#                  Filename                       Text Cleaned_Filename
# 0      Talib Kweli_lyrics      Lyrics of Talib Kweli      Talib Kweli
# 1  CunninLynguists_lyrics  Lyrics of CunninLynguists  CunninLynguists
# 2       Kanye West_lyrics       Lyrics of Kanye West       Kanye West
# 3    Deniro Farrar_lyrics    Lyrics of Deniro Farrar    Deniro Farrar
# 4           Eminem_lyrics           Lyrics of Eminem           Eminem

# %%
import pandas as pd

# 示例数据
metadata_data = {
    'Artist': ['Talib Kweli', 'CunninLynguists', 'Kanye West', 'Deniro Farrar', 'Eminem'],
    'File': ['Talib Kweli_lyrics.txt', 'CunninLynguists_lyrics.txt', 'Kanye West_lyrics.txt', 'Deniro Farrar_lyrics.txt', 'Eminem_lyrics.txt']
}

lyrics_data = {
    'Filename': ['Talib Kweli_lyrics', 'CunninLynguists_lyrics', 'Kanye West_lyrics', 'Deniro Farrar_lyrics', 'Eminem_lyrics'],
    'Text': ['Lyrics of Talib Kweli', 'Lyrics of CunninLynguists', 'Lyrics of Kanye West', 'Lyrics of Deniro Farrar', 'Lyrics of Eminem']
}

# 转换为DataFrame
metadata_df = pd.DataFrame(metadata_data)
lyrics_df = pd.DataFrame(lyrics_data)

# 清理文件名并尝试匹配
metadata_df['Cleaned_File'] = metadata_df['File'].str.replace(r'_lyrics\.txt$', '', regex=True)
lyrics_df['Cleaned_Filename'] = lyrics_df['Filename'].str.replace(r'_lyrics$', '', regex=True)

# 合并DataFrame
merged_df = metadata_df.merge(lyrics_df, left_on='Cleaned_File', right_on='Cleaned_Filename')

# 显示结果
print(merged_df[['Artist', 'File', 'Filename', 'Text']])
# Out:
#             Artist                        File                Filename  \
# 0      Talib Kweli      Talib Kweli_lyrics.txt      Talib Kweli_lyrics
# 1  CunninLynguists  CunninLynguists_lyrics.txt  CunninLynguists_lyrics
# 2       Kanye West       Kanye West_lyrics.txt       Kanye West_lyrics
# 3    Deniro Farrar    Deniro Farrar_lyrics.txt    Deniro Farrar_lyrics
# 4           Eminem           Eminem_lyrics.txt           Eminem_lyrics
#
#                         Text
# 0      Lyrics of Talib Kweli
# 1  Lyrics of CunninLynguists
# 2       Lyrics of Kanye West
# 3    Lyrics of Deniro Farrar
# 4           Lyrics of Eminem

# %%
# Merge metadata and lyrics_df into new DataFrame
# Will only keep rows where both metadata and lyrics_df are present
merged_df = metadata_df.merge(lyrics_df, left_on='File', right_on='Filename')

# %%
average_pos_df = average_pos_df.reset_index(drop=True)
